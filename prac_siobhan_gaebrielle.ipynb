# %% [markdown]
# <a href="https://colab.research.google.com/github/siomai1004/comsci2-PRAC-exercise/blob/main/prac_siobhan_gaebrielle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Is a Number Even or Odd
num = int(input("Enter a number: "))

# This can calculate if the input is even or odd
if num % 2 == 0:
  print(num, "is even")
else:
  print(num, "is odd")
# Out:
# Enter a number: 67
# 67 is odd
